# %%
import pandas as pd
df = pd.read_table(filepath_or_buffer='./clinical/nationwidechildrens.org_clinical_patient_prad.txt', sep='\t', encoding='utf-8')
df.head()
# Out:
#                        bcr_patient_uuid  bcr_patient_barcode  \
# 0                      bcr_patient_uuid  bcr_patient_barcode
# 1                               CDE_ID:       CDE_ID:2003301
# 2  49197847-CC83-4CE1-8397-D09CEA4C4928         TCGA-2A-A8VL
# 3  91C0D161-2B59-4B7A-8C19-6D26DEA31849         TCGA-2A-A8VO
# 4  931B549F-B9F2-4E8D-83ED-FF663671883C         TCGA-2A-A8VT
#
#    form_completion_date                 histologic_diagnosis  \
# 0  form_completion_date                    histological_type
# 1               CDE_ID:                       CDE_ID:3081934
# 2             2014-3-29  Prostate Adenocarcinoma Acinar Type
# 3             2014-3-30  Prostate Adenocarcinoma Acinar Type
# 4             2014-3-29  Prostate Adenocarcinoma Acinar Type
#
#   histologic_diagnosis_other                zone_of_origin  \
# 0    histological_type_other                zone_of_origin
# 1             CDE_ID:3124492                  CDE_ID:65104
# ...

# %%
df.head()
# Out:
#                        bcr_patient_uuid  bcr_patient_barcode  \
# 0                      bcr_patient_uuid  bcr_patient_barcode
# 1                               CDE_ID:       CDE_ID:2003301
# 2  49197847-CC83-4CE1-8397-D09CEA4C4928         TCGA-2A-A8VL
# 3  91C0D161-2B59-4B7A-8C19-6D26DEA31849         TCGA-2A-A8VO
# 4  931B549F-B9F2-4E8D-83ED-FF663671883C         TCGA-2A-A8VT
#
#    form_completion_date                 histologic_diagnosis  \
# 0  form_completion_date                    histological_type
# 1               CDE_ID:                       CDE_ID:3081934
# 2             2014-3-29  Prostate Adenocarcinoma Acinar Type
# 3             2014-3-30  Prostate Adenocarcinoma Acinar Type
# 4             2014-3-29  Prostate Adenocarcinoma Acinar Type
#
#   histologic_diagnosis_other                zone_of_origin  \
# 0    histological_type_other                zone_of_origin
# 1             CDE_ID:3124492                  CDE_ID:65104
# ...
